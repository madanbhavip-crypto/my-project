# %% [markdown]
# Basic input output

# %%
name = input("enter your name:")
print(name)
# Out:
# enter your name: PRIYA
# PRIYA

# %%
cgpa = int(input("enter your cgpa:"))
print(cgpa)
# Out:
# enter your cgpa: 8
# 8
