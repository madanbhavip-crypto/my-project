# %% [markdown]
# ## Data Collection CSV
#
# This code connects to the ESP32 through the COM Port and receivesthe serially transmitted data from the ESP32. This data is then
# saved as a `.csv` file for later use.

# %% [markdown]
# ### Importing Libraries
#
# This block of code imports the necessary libraries for the program. It also defines the `COM` port and the name of the file we are sending to.

# %%
import serial
import pandas as pd
import time
import os

PORT         = 'COM5'                
DATASET_FILE = 'mlws.csv'

# %% [markdown]
# ### Defining a Function
#
# Here, we define a new function to be able to decode the incoming serial stream of data from the `ESP32` and save it into the `DATASET_FILE`

# %%
def collect_samples(label, num_samples=15):
    ser = serial.Serial(PORT, 115200, timeout=2)
    time.sleep(2)  # Wait for serial to stabilize
    ser.reset_input_buffer()
    collected = 0

    print(f"Collecting {num_samples} samples for: '{label}'")
    print("Hold button → draw gesture → release.\n")

    while collected < num_samples:
        input(f"  [{collected+1}/{num_samples}] Draw, then press Enter '{label}'...")
        rows = []

        # Wait until button is pressed (ESP sends IMU data, not IDLE)
        while True:
            line = ser.readline().decode(errors='ignore').strip()
            if ',' in line:
                rows.append(line.split(','))
                break

        # Keep reading until button is released (ESP sends IDLE)
        while True:
            line = ser.readline().decode(errors='ignore').strip()
            if line == 'IDLE':
                break
            if ',' in line:
                rows.append(line.split(','))

        if len(rows) < 5:
            print("  Too short, skipping.")
            continue

        # Save to CSV
        df = pd.DataFrame(rows, columns=['ax','ay','az','gx','gy','gz'])
        df['label']     = label
        df['sample_id'] = f"{label}_{collected}"
        df.to_csv(DATASET_FILE, mode='a', header=not os.path.exists(DATASET_FILE), index=False)

        collected += 1
        print(f"Saved ({len(rows)} rows)")

    ser.close()
    print(f"Done! {num_samples} samples saved for '{label}'.\n")

# %% [markdown]
# ### Collecting the data
# Here, we collect the data samples for each class `(0-9 , +, - & =)`

# %%
collect_samples(0)
# Out:
# ...
# Hold button → draw gesture → release.

# %%
collect_samples(1)
# Out:
# ...
# Hold button → draw gesture → release.
#   [1/15] Draw, then press Enter '1'...
# Saved (93 rows)
#   [2/15] Draw, then press Enter '1'...
# Saved (55 rows)
#   [3/15] Draw, then press Enter '1'...
# Saved (66 rows)
#   [4/15] Draw, then press Enter '1'...
# Saved (126 rows)
#   [5/15] Draw, then press Enter '1'...
# Saved (148 rows)
#   [6/15] Draw, then press Enter '1'...
# Saved (158 rows)
#   [7/15] Draw, then press Enter '1'...
# Saved (180 rows)
#   [8/15] Draw, then press Enter '1'...
# Saved (86 rows)
#   [9/15] Draw, then press Enter '1'...
# Saved (66 rows)
#   [10/15] Draw, then press Enter '1'...
# Saved (91 rows)
#   [11/15] Draw, then press Enter '1'...
# Saved (109 rows)
#   [12/15] Draw, then press Enter '1'...
# Saved (112 rows)
#   [13/15] Draw, then press Enter '1'...
# Saved (87 rows)
#   [14/15] Draw, then press Enter '1'...
# Saved (157 rows)
#   [15/15] Draw, then press Enter '1'...
# Saved (50 rows)
# Done! 15 samples saved for '1'.

# %%
collect_samples(3)
# Out:
# ...
# Hold button → draw gesture → release.
#   [1/15] Draw, then press Enter '3'...
# Saved (172 rows)
#   [2/15] Draw, then press Enter '3'...
# Saved (160 rows)
#   [3/15] Draw, then press Enter '3'...
# Saved (155 rows)
#   [4/15] Draw, then press Enter '3'...
# Saved (189 rows)
#   [5/15] Draw, then press Enter '3'...
# Saved (144 rows)
#   [6/15] Draw, then press Enter '3'...
# Saved (134 rows)
#   [7/15] Draw, then press Enter '3'...
# Saved (126 rows)
#   [8/15] Draw, then press Enter '3'...
# Saved (107 rows)
#   [9/15] Draw, then press Enter '3'...
# Saved (113 rows)
#   [10/15] Draw, then press Enter '3'...
# Saved (132 rows)
#   [11/15] Draw, then press Enter '3'...
# Saved (291 rows)
#   [12/15] Draw, then press Enter '3'...
# Saved (130 rows)
#   [13/15] Draw, then press Enter '3'...
# Saved (149 rows)
#   [14/15] Draw, then press Enter '3'...
# Saved (127 rows)
#   [15/15] Draw, then press Enter '3'...
# Saved (122 rows)
# Done! 15 samples saved for '3'.
